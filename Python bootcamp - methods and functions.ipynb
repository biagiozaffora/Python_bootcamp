# %% [markdown]
# # Section 6 : Methods and functions
#
# ***
#
# ## Looking for available methods

# %%
mylist = [1, 2, 3]

# %%
mylist.append(4)
mylist
# Out:
# [1, 2, 3, 4]

# %%
mylist.pop()
mylist
# Out:
# [1, 2, 3]

# %% [markdown]
# To discover all the available methods associated with an object type we can simply tape the name of the object followed by dot and than hit tab :
#
# For instance :
#
# `mylist.` + TAB
#
# I can also get call the help over a method by writing the method and than executing the following :
#
# `mylist.insert`+ SHIFT + TAB
#
# or
#
# `help(mylist.insert)`

# %%
# insert 0 at index 1
mylist.insert(1, 0)
mylist
# Out:
# [1, 0, 2, 3]

# %% [markdown]
# ***
#
# ## Functions
#
# 'snake casing' : all lower case names with underscores :
#
# `def name_of_function(name):`
# `    '''
#     Docstring explains function
#     '''
# `
#
# `    print("Hello" + name)`
#
# For classes we will se 'camel casing'.
#
# We usually use `return` as this allows us to save the result obtained by applying a function to some variable.

# %%
def add_numbers(num1, num2):
    return num1+ num2

result = add_numbers(1, 79)
print(result)
# Out:
# 80

# %% [markdown]
# ### Basic functions

# %%
def say_hello():
    print('Hello')
    print('How are you')

# %%
say_hello()
# Out:
# Hello
# How are you

# %%
# This just reminds us that say_hello is a function
say_hello
# Out:
# <function __main__.say_hello()>

# %%
# use a default value to name
def say_hello(name='Default'):
    print('Hello {}'.format(name))

# %%
say_hello('Biagio')
# Out:
# Hello Biagio

# %%
say_hello()
# Out:
# Hello Default

# %%
# Return will alow to save the value returned by the function
def add_num(num1, num2):
    return num1 + num2

# %%
result = add_num(1, 55555)
print(result)
# Out:
# 55556

# %%
# Careful with this situation because the type of the data should be checked
def sum_numbers(num1, num2):
    return num1 + num2

# %%
sum_numbers('abc', '10')
# Out:
# 'abc10'

# %% [markdown]
# ### Functions with logic

# %%
def is_even(number):
    if number % 2 == 0:
        print('The number {} is even'.format(number))
    else:
        print('The number {} is odd'.format(number))

# %%
is_even(2)
# Out:
# The number 2 is even

# %%
is_even(47)
# Out:
# The number 47 is odd

# %%
def elem_in_list_is_even(a_list):
    bool_list = []
    for i in range(0, len(a_list)):
        bool_list.append(a_list[i] % 2 == 0)
    return bool_list

# %%
elem_in_list_is_even([1, 2, 3, 4, 5, 6, 7, 8, 9])
# Out:
# [False, True, False, True, False, True, False, True, False]

# %% [markdown]
# ### Functions and tuple unpacking

# %%
stock_prices = [('APPL', 200), ('GOOG', 400), ('MSFT', 100)]

for item in stock_prices:
    print(item)
# Out:
# ('APPL', 200)
# ('GOOG', 400)
# ('MSFT', 100)

# %%
for ticker, price in stock_prices:
    print('The price associated with ticker {} is {}'.format(ticker, price))
# Out:
# The price associated with ticker APPL is 200
# The price associated with ticker GOOG is 400
# The price associated with ticker MSFT is 100

# %%
work_hours = [('Abby', 100), ('Billy', 400), ('Cassy', 800)]

# %%
def employee_of_year(a_list):
    best_employee = [('unknown', 0)]
    for name, hours in a_list:
        if hours > best_employee[0][1]:
            best_employee[0] = name, hours
        else:
            pass
    return best_employee[0]

# %%
employee_of_year(work_hours)
# Out:
# ('Cassy', 800)

# %%
work_hours = [('Abby', 100), ('Billy', 4000), ('Cassy', 800)]

# %%
employee_of_year(work_hours)
# Out:
# ('Billy', 4000)

# %%
name, hours = employee_of_year(work_hours)
print(name)
print(hours)
# Out:
# Billy
# 4000

# %% [markdown]
# ### Interactions between functions

# %%
example = [1, 2, 3, 4, 5, 6, 7]

# %%
# shuffle the list in place
from random import shuffle
shuffle(example)
example
# Out:
# [2, 1, 6, 5, 4, 3, 7]

# %%
def shuffle_list(mylist):
    shuffle(mylist)
    return mylist

# %%
result = shuffle_list(example)
result
# Out:
# [1, 4, 5, 7, 6, 3, 2]

# %%
mylist = [' ', 'O', ' ']

# %%
shuffle_list(mylist)
# Out:
# [' ', ' ', 'O']

# %%
def player_guess():
    
    guess = ''
    
    while guess not in ['0', '1', '2']:
        guess = input('Pick a number: 0, 1 or 2')
        
    return int(guess)

# %%
player_guess()
# Out:
# Pick a number: 0, 1 or 22
# 2

# %%
def check_guess(mylist, guess):
    if mylist[guess] == '0':
        print('Correct')
    else:
        print('Wrong guess')
        print(mylist)

# %%
# INITIAL LIST
mylist = [' ', 'O', ' ']

# SHUFFLE LIST
mixedup_list = shuffle_list(mylist)

# USE GUESS
guess = player_guess()

# CHECK GUESS
check_guess(mixedup_list, guess)
# Out:
# Pick a number: 0, 1 or 22
# Wrong guess
# ['O', ' ', ' ']

# %% [markdown]
# ### $^*$args and $^{**}$kwargs
#
# - `*args`-> arguments (produces tuples)
#
# - `**kwargs` -> keyword arguments (produces dictionaries)
#
# Allows to pass some arguments to a function without being too specific.

# %%
def myfunc(a, b):
    # Returns 5 percent of the sum of a and b
    return sum((a, b)) * 0.05

# %%
myfunc(40, 60)
# Out:
# 5.0

# %% [markdown]
# In the previous function `a`and `b` are positional argument. What if I have more numbers?

# %%
def myfunc(a, b, c=0, d=0, e=0):
    # Returns 5 percent of the sum of a and b
    return sum((a, b, c, d, e)) * 0.05

# %%
myfunc(40, 60, 100)
# Out:
# 10.0

# %%
# If I use args I can pass all the arguments that I want without generating an error now.
# *args will be treated as tuples

def myfunc(*args):
    return sum(args) * 0.05

# %%
myfunc(2, 4, 6, 8, 10)
# Out:
# 1.5

# %%
def myfunc(**kwargs):
    print(kwargs)
    if 'fruit' in kwargs:
        print('My fruit of choice is {}'.format(kwargs['fruit']))
    else:
        print('I did not find any fruit here')

# %%
myfunc(fruit='apple', veggie='lettuce')
# Out:
# {'fruit': 'apple', 'veggie': 'lettuce'}
# My fruit of choice is apple

# %%
def myfunc(*args, **kwargs):
    print(args)
    print(kwargs)
    print('I would like {} {}'.format(args[0], kwargs['food']))

# %%
myfunc(10, 20, 30, fruit='orange', food='eggs', animal='dog')
# Out:
# (10, 20, 30)
# {'fruit': 'orange', 'food': 'eggs', 'animal': 'dog'}
# I would like 10 eggs

# %% [markdown]
# Create a function that accept a string and return the same string with alternating upper and lower case letters dependending on the fact that their position is even (upper case) or odd (lower case).

# %%
def myfunc(a_string):
    
    new_string = []
    count = 0
    for letter in a_string:
        if count == 0:
            new_string.append(letter.upper())
        elif count % 2 == 0:
            new_string.append(letter.upper())
        else:
            new_string.append(letter)
        count += 1
    s = ''
    return s.join(new_string)

# %%
myfunc('supercalifragilistichespiralidoso')
# Out:
# 'SuPeRcAlIfRaGiLiStIcHeSpIrAlIdOsO'

# %% [markdown]
# ### Lambda expressions, map and filter
#
# Lambda expressions are used to create anonymus functions, meaning functions that are not named and used only once. But first let us start dicussing `map` and `filter` functions.
#
# - `map` allows to apply a function to every object element (for instance all the elements of a list)
#
# - `filter` allows to apply a function and return filtered items based on a condition.

# %%
# map(func, *iterable)
def square(num):
    return num ** 2

# %%
mylist = [1, 2, 3, 4, 5]

for item in map(square, mylist):
    print(item)
# Out:
# 1
# 4
# 9
# 16
# 25

# %%
list(map(square, mylist))
# Out:
# [1, 4, 9, 16, 25]

# %%
def splicer(name):
    if len(name)%2 == 0:
        return 'EVEN'
    else:
        return name[0]

# %%
names = ['Andy', 'Eve', 'Biagio']
list(map(splicer, names))
# Out:
# ['EVEN', 'E', 'EVEN']

# %%
# Filter
def check_even(num):
    return num % 2 == 0

# %%
mylist = [1,2,3,4,5,6]
list(filter(check_even, mylist))
# Out:
# [2, 4, 6]

# %%
# lampbda expression
def square(num):
    result =  num ** 2
    return result
square(4)
# Out:
# 16

# %%
# Equivalently :
def square(num):
    return num ** 2
square(4)
# Out:
# 16

# %%
# Equivalently :
def square(num): return num ** 2
square(4)
# Out:
# 16

# %%
# We can do something like this but there is no need to assign the lambda function to a variable.
# Instead we can use the lambda expression ssociated with map and filter
square = lambda num : num ** 2
square(4)
# Out:
# 16

# %%
mynums = [1,2,3,4,5]
list(map(lambda num : num**2, mynums))
# Out:
# [1, 4, 9, 16, 25]

# %%
list(filter(lambda num : num % 2 == 0, mylist))
# Out:
# [2, 4, 6]

# %%
mystrings = ['abc', 'def', 'ghi']

list(map(lambda string : string[0], mystrings))
# Out:
# ['a', 'd', 'g']

# %% [markdown]
# ### Nested statements and scope
